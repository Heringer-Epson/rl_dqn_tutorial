# %% [markdown]
# # PyTorch Tutorial
#
# * Source: https://docs.pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
#
# ### Resources
#
# * Installation of Jupyter Notebook: https://www.youtube.com/watch?v=suAkMeWJ1yE
# * To allow virtual env access, on the command line run:
#   * `> Set-ExecutionPolicy Unrestricted -Scope Process`
#   * See https://stackoverflow.com/questions/18713086/virtualenv-wont-activate-on-windows
# * Create virtual environment:
#   * `> python -m venv dqn_tutorial`
#   * `> .\dqn_tutorial\Scripts\activate`
#   * `> pip install -r requirements.txt`

# %%
print(5)
# Out:
# 5

# %%
print(3)
# Out:
# 3
